# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 1
# ## Congratulations on making it to your first milestone!
# You've already learned a ton and are ready to work on a real project.
#
# Your assignment: Create a Tic Tac Toe game. You are free to use any IDE you like.
#
# Here are the requirements:
#
# * 2 players should be able to play the game (both sitting at the same computer)
# * The board should be printed out every time a player makes a move
# * You should be able to accept input of the player position and then place a symbol on the board
#
# Feel free to use Google to help you figure anything out (but don't just Google "Tic Tac Toe in Python" otherwise you won't learn anything!) Keep in mind that this project can take anywhere between several hours to several days.
#
# There are 4 Jupyter Notebooks related to this assignment:
#
# * This Assignment Notebook
# * A "Walkthrough Steps Workbook" Notebook
# * A "Complete Walkthrough Solution" Notebook
# * An "Advanced Solution" Notebook
#
# I encourage you to just try to start the project on your own without referencing any of the notebooks. If you get stuck, check out the next lecture which is a text lecture with helpful hints and steps. If you're still stuck after that, then check out the Walkthrough Steps Workbook, which breaks up the project in steps for you to solve. Still stuck? Then check out the Complete Walkthrough Solution video for more help on approaching the project!

# %% [markdown]
# There are parts of this that will be a struggle...and that is good! I have complete faith that if you have made it this far through the course you have all the tools and knowledge to tackle this project. Remember, it's totally open book, so take your time, do a little research, and remember:
#
# ## HAVE FUN!

# %%
from IPython.display import clear_output

def elegir_fichas():
    
    jugador1_ficha = ""
    jugador2_ficha = ""

    while not (jugador1_ficha == "X" or jugador1_ficha == "O"):
        jugador1_ficha = input ("Jugador 1, escoja ficha (X) o (O): ")
        clear_output()
        if jugador1_ficha == "X":
            jugador2_ficha = "O"
        else:
            jugador2_ficha = "X"

    return (jugador1_ficha, jugador2_ficha)

# %%
def pintar_tablero(ficha,tablero):
    
    tirada = 0
    
    while tirada not in range(1, 9+1):
        tirada = int(input ("\nElija coordenadas (1-9): "))
        clear_output
        
        #clear_output
        
        if tablero[tirada] != " ":
            print("\nERROR, casilla ocupada\n")
            clear_output
        else:
            tablero[tirada] = ficha
    
            print("\n")
            print("{} | {} | {}".format(tablero[7], tablero[8], tablero[9]))
            print("---------")
            print("{} | {} | {}".format(tablero[4], tablero[5], tablero[6]))
            print("---------")
            print("{} | {} | {}".format(tablero[1], tablero[2], tablero[3]))

# %%
def ganador():
    
    if (((tablero[1] == "X") and (tablero[2] == "X") and (tablero[3] == "X")) or
        ((tablero[4] == "X") and (tablero[5] == "X") and (tablero[6] == "X")) or
        ((tablero[7] == "X") and (tablero[8] == "X") and (tablero[9] == "X")) or
        ((tablero[1] == "X") and (tablero[4] == "X") and (tablero[7] == "X")) or
        ((tablero[2] == "X") and (tablero[5] == "X") and (tablero[8] == "X")) or
        ((tablero[3] == "X") and (tablero[6] == "X") and (tablero[9] == "X")) or
        ((tablero[1] == "X") and (tablero[5] == "X") and (tablero[9] == "X")) or
        ((tablero[3] == "X") and (tablero[5] == "X") and (tablero[7] == "X")) or
        
        ((tablero[1] == "O") and (tablero[2] == "O") and (tablero[3] == "O")) or
        ((tablero[4] == "O") and (tablero[5] == "O") and (tablero[6] == "O")) or
        ((tablero[7] == "O") and (tablero[8] == "O") and (tablero[9] == "O")) or
        ((tablero[1] == "O") and (tablero[4] == "O") and (tablero[7] == "O")) or
        ((tablero[2] == "O") and (tablero[5] == "O") and (tablero[8] == "O")) or
        ((tablero[3] == "O") and (tablero[6] == "O") and (tablero[9] == "O")) or
        ((tablero[1] == "O") and (tablero[5] == "O") and (tablero[9] == "O")) or
        ((tablero[3] == "O") and (tablero[5] == "O") and (tablero[7] == "O"))):
        
            return True
    else:
            return False

# %%
tablero = {1: " ", 2: " ", 3: " ",
           4: " ", 5: " ", 6: " ",
           7: " ", 8: " ", 9: " "}
    
jug1_ficha, jug2_ficha = elegir_fichas()

while not all(value == "X" or value == "O" for value in tablero.values()):
    print ("\nTurno jugador 1: ")
    pintar_tablero(jug1_ficha, tablero)
    if ganador():
        print("\n¡¡GANADOR JUGADOR 1!!")
        break
        #pass
    else:
        print ("\nTurno jugador 2: ")
        pintar_tablero(jug2_ficha, tablero)
        if ganador():
              print("\n¡¡GANADOR JUGADOR 2 !!")
              break
# Out:
# Turno jugador 1:
#
# Elija coordenadas (1-9): 1
#
#
#   |   |
# ---------
#   |   |
# ---------
# X |   |
#
# Turno jugador 2:
#
# Elija coordenadas (1-9): 2
#
#
#   |   |
# ---------
#   |   |
# ---------
# X | O |
#
# Turno jugador 1:
#
# Elija coordenadas (1-9): 3
#
#
#   |   |
# ---------
#   |   |
# ---------
# X | O | X
#
# Turno jugador 2:
#
# Elija coordenadas (1-9): 4
#
#
#   |   |
# ---------
# O |   |
# ---------
# X | O | X
#
# Turno jugador 1:
#
# Elija coordenadas (1-9): 5
#
#
#   |   |
# ---------
# O | X |
# ---------
# X | O | X
#
# Turno jugador 2:
#
# Elija coordenadas (1-9): 6
#
#
#   |   |
# ---------
# O | X | O
# ---------
# X | O | X
#
# Turno jugador 1:
#
# Elija coordenadas (1-9): 8
#
#
#   | X |
# ---------
# O | X | O
# ---------
# X | O | X
#
# Turno jugador 2:
#
# Elija coordenadas (1-9): 7
#
#
# O | X |
# ---------
# O | X | O
# ---------
# X | O | X
#
# Turno jugador 1:
#
# Elija coordenadas (1-9): 9
#
#
# O | X | X
# ---------
# O | X | O
# ---------
# ...
